# %%
import interlo as iso
from astropy import units as u

# %%
stars = iso.Starset(num_stars = 1, r_extent=.3)
stars.get_isos(v_eject=1,num_per_star=1000)
stars.integrate()
stars.animate_position()
# Out:
# <video width="2000" height="1000" controls autoplay loop>
#   <source type="video/mp4" src="...
